# %%
import pandas as pd
url = "https://ko.wikipedia.org/wiki/%EC%98%AC%EB%A6%BC%ED%94%BD_%EB%A9%94%EB%8B%AC_%EC%A7%91%EA%B3%84"
df = pd.read_html(url)
df
# Out:
# [             국가 (IOC 코드)  하계 참가 횟수  Unnamed: 2  Unnamed: 3  Unnamed: 4      계  \
#  0           아프가니스탄 (AFG)        14           0           0           2      2
#  1              알제리 (ALG)        13           5           4           8     17
#  2            아르헨티나 (ARG)        24          21          25          28     74
#  3            아르메니아 (ARM)         6           2           6           6     14
#  4    오스트랄라시아 (ANZ) [ANZ]         2           3           4           5     12
#  ..                   ...       ...         ...         ...         ...    ...
#  148       독립 (IOA) [IOA]         3           1           0           1      2
#  149    독립 참가 (IOP) [IOP]         1           0           1           2      3
#  150  러시아 출신 올림픽 선수 (OAR)         0           0           0           0      0
#  151       혼성 (ZZX) [ZZX]         3           8           5           4     17
#  152                   총합        28        5116        5082        5490  15688
#
# ...

# %%
len(df)
# Out:
# 10

# %%
df[0]
# Out:
#              국가 (IOC 코드)  하계 참가 횟수  Unnamed: 2  Unnamed: 3  Unnamed: 4      계  \
# 0           아프가니스탄 (AFG)        14           0           0           2      2
# 1              알제리 (ALG)        13           5           4           8     17
# 2            아르헨티나 (ARG)        24          21          25          28     74
# 3            아르메니아 (ARM)         6           2           6           6     14
# 4    오스트랄라시아 (ANZ) [ANZ]         2           3           4           5     12
# ..                   ...       ...         ...         ...         ...    ...
# 148       독립 (IOA) [IOA]         3           1           0           1      2
# 149    독립 참가 (IOP) [IOP]         1           0           1           2      3
# 150  러시아 출신 올림픽 선수 (OAR)         0           0           0           0      0
# 151       혼성 (ZZX) [ZZX]         3           8           5           4     17
# 152                   총합        28        5116        5082        5490  15688
#
# ...

# %%
df = pd.read_html(url, header=0,index_col=0) #헤더를 열이름으로, 나라이름을 행이름으로 지정하기위해 설정
df[0]
# Out:
#                      하계 참가 횟수  Unnamed: 2  Unnamed: 3  Unnamed: 4      계  \
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)               14           0           0           2      2
# 알제리 (ALG)                  13           5           4           8     17
# 아르헨티나 (ARG)                24          21          25          28     74
# 아르메니아 (ARM)                 6           2           6           6     14
# 오스트랄라시아 (ANZ) [ANZ]         2           3           4           5     12
# ...                       ...         ...         ...         ...    ...
# 독립 (IOA) [IOA]              3           1           0           1      2
# 독립 참가 (IOP) [IOP]           1           0           1           2      3
# 러시아 출신 올림픽 선수 (OAR)         0           0           0           0      0
# 혼성 (ZZX) [ZZX]              3           8           5           4     17
# 총합                         28        5116        5082        5490  15688
#
#                      동계 참가 횟수  Unnamed: 7  Unnamed: 8  Unnamed: 9   계.1  \
# ...

# %%
# 슬라이싱을 활욜한 하계올림픽에 대한 데이터 추출
a= df[0].iloc[:,:5] #행은 전체 열은 0~4까지 (a= df[0].iloc[0:len(),0:5])
a
# Out:
#                      하계 참가 횟수  Unnamed: 2  Unnamed: 3  Unnamed: 4      계
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)               14           0           0           2      2
# 알제리 (ALG)                  13           5           4           8     17
# 아르헨티나 (ARG)                24          21          25          28     74
# 아르메니아 (ARM)                 6           2           6           6     14
# 오스트랄라시아 (ANZ) [ANZ]         2           3           4           5     12
# ...                       ...         ...         ...         ...    ...
# 독립 (IOA) [IOA]              3           1           0           1      2
# 독립 참가 (IOP) [IOP]           1           0           1           2      3
# 러시아 출신 올림픽 선수 (OAR)         0           0           0           0      0
# 혼성 (ZZX) [ZZX]              3           8           5           4     17
# 총합                         28        5116        5082        5490  15688
#
# [153 rows x 5 columns]

# %%
# 컬럼명 중 unnamed 부분 컬럼명 설정하기
a.columns = ['하계 참가 횟수','금','은','동','계']
a
# Out:
#                               하계 참가 횟수     금     은     동      계
# 국가 (IOC 코드)
# 총합                                  28  5116  5082  5490  15688
# 미국 (USA) [P] [Q] [R] [Z] [F]        27  1022   795   706   2523
# 소련 (URS) [URS]                       9   395   319   296   1010
# 영국 (GBR) [GBR] [Z]                  28   263   295   293    851
# 중화인민공화국 (CHN) [CHN]                 10   224   167   155    546
# ...                                ...   ...   ...   ...    ...
# 리히텐슈타인 (LIE)                        17     0     0     0      0
# 쿠웨이트 (KUW)                          12     0     0     2      2
# 북마케도니아 (MKD)                         6     0     0     1      1
# 말레이시아 (MAS) [MAS]                   13     0     7     4     11
# 아프가니스탄 (AFG)                        14     0     0     2      2
#
# [153 rows x 5 columns]

# %%
# 금메달 기준 내림차순 정렬하기
a= a.sort_values(by=['금'],ascending=False)
a
# Out:
#                               하계, 참가 횟수     금     은     동      계
# 국가 (IOC 코드)
# 총합                                   28  5116  5082  5490  15688
# 미국 (USA) [P] [Q] [R] [Z] [F]         27  1022   795   706   2523
# 소련 (URS) [URS]                        9   395   319   296   1010
# 영국 (GBR) [GBR] [Z]                   28   263   295   293    851
# 중화인민공화국 (CHN) [CHN]                  10   224   167   155    546
# ...                                 ...   ...   ...   ...    ...
# 리히텐슈타인 (LIE)                         17     0     0     0      0
# 쿠웨이트 (KUW)                           12     0     0     2      2
# 북마케도니아 (MKD)                          6     0     0     1      1
# 말레이시아 (MAS) [MAS]                    13     0     7     4     11
# 아프가니스탄 (AFG)                         14     0     0     2      2
#
# [153 rows x 5 columns]

# %%
#csv 파일로 저장하기
a.to_csv('summer_medal.csv')

# %% [markdown]
# # 데이터 시각화 하기

# %%
import matplotlib.pyplot as plt

plt.rc('font',family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('ggplot')
a.plot()
# Out:
# <AxesSubplot:xlabel='국가 (IOC 코드)'>

# %%
# 금메달이 가장 많은 상위 10개국만 그래프로 표현하기
a[1:11].plot()
# Out:
# <AxesSubplot:xlabel='국가 (IOC 코드)'>

# %%
# 막대 그래프로 금메달이 가장 많은 상위 10개국만 그래프로 표현하기
a[1:11].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='국가 (IOC 코드)'>
