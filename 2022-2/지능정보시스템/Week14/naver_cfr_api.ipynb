# %% [markdown]
# # 실습1 (201701633_전민영)

# %% [markdown]
# ![son.jpg](attachment:son.jpg)

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import requests  # pip install requests
client_id = "AoakXDTB44bQrc9XdCnw"
client_secret = "PpxHgwXhhS"
# url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식
files = {'image': open('son.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":340,"height":486},"faceCount":1},"faces":[{"celebrity":{"value":"손흥민","confidence":0.722389}}]}

# %% [markdown]
# ### 손흥민의 사진으로 유명인 얼굴인식을 한 결과 72%의 확률로 손흥민이라고 분석을 하였고 사진의 크기는 "width":340,"height":486 라고 분석했다.

# %%
import os
import sys
import requests  # pip install requests
client_id = "AoakXDTB44bQrc9XdCnw"
client_secret = "PpxHgwXhhS"
url = "https://openapi.naver.com/v1/vision/face" # 얼굴감지
#url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식
files = {'image': open('son.jpg', 'rb')}
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":340,"height":486},"faceCount":1},"faces":[{"roi":{"x":116,"y":126,"width":86,"height":86},"landmark":{"leftEye":{"x":139,"y":146},"rightEye":{"x":175,"y":146},"nose":{"x":157,"y":168},"leftMouth":{"x":141,"y":193},"rightMouth":{"x":176,"y":192}},"gender":{"value":"male","confidence":1.0},"age":{"value":"29~33","confidence":1.0},"emotion":{"value":"neutral","confidence":0.999998},"pose":{"value":"frontal_face","confidence":0.999806}}]}

# %% [markdown]
# ### 손흥민의 사진을 이용해 얼굴감지를 한 결과 남자를 100%로 분석했고 나이는 29~33세라고 100% , 감정은 기쁘지도 슬프지도 않은 중간 상태라고 99%로 분석했고, 얼굴은 앞 모습이라고 99%의 확률로 분석했다.
