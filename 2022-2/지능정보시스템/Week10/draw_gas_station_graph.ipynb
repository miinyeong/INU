# %%
pip install --upgrade ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\minye\anaconda3\lib\site-packages (7.6.5)
# Collecting ipywidgets
#   Using cached ipywidgets-8.0.2-py3-none-any.whl (134 kB)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\minye\anaconda3\lib\site-packages (from ipywidgets) (8.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\minye\anaconda3\lib\site-packages (from ipywidgets) (5.1.1)
# Collecting jupyterlab-widgets~=3.0
#   Using cached jupyterlab_widgets-3.0.3-py3-none-any.whl (384 kB)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\minye\anaconda3\lib\site-packages (from ipywidgets) (6.9.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\minye\anaconda3\lib\site-packages (from ipywidgets) (4.0.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\minye\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\minye\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\users\minye\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\minye\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\minye\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: backcall in c:\users\minye\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\minye\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\minye\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: colorama in c:\users\minye\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.4)
# Requirement already satisfied: stack-data in c:\users\minye\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\minye\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (61.2.0)
# Requirement already satisfied: decorator in c:\users\minye\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\minye\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\minye\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.11.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\minye\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\minye\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\minye\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (4.9.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\minye\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\minye\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (302)
# Requirement already satisfied: wcwidth in c:\users\minye\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\minye\anaconda3\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: asttokens in c:\users\minye\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# Requirement already satisfied: pure-eval in c:\users\minye\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: executing in c:\users\minye\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Installing collected packages: jupyterlab-widgets, ipywidgets
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.5
#     Uninstalling ipywidgets-7.6.5:
#       Successfully uninstalled ipywidgets-7.6.5
# Successfully installed ipywidgets-8.0.2 jupyterlab-widgets-3.0.3

# %%
pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\minye\anaconda3\lib\site-packages (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)

# %%
from glob import glob

# %%
station_files = glob('지역*.xls')
station_files
# Out:
# ['지역_위치별(주유소) (1).xls',
#  '지역_위치별(주유소) (2).xls',
#  '지역_위치별(주유소) (3).xls',
#  '지역_위치별(주유소) (4).xls',
#  '지역_위치별(주유소) (5).xls',
#  '지역_위치별(주유소) (6).xls',
#  '지역_위치별(주유소) (7).xls',
#  '지역_위치별(주유소) (8).xls',
#  '지역_위치별(주유소) (9).xls',
#  '지역_위치별(주유소).xls']

# %%
import pandas as pd

tmp_list = []

for file_name in station_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_list.append(tmp)
    
tmp_list[0]
# Out:
#        지역                     상호                       주소      상표  \
# 0   인천광역시                원천제2주유소           인천 계양구 벌말로 295   알뜰주유소
# 1   인천광역시          씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL
# 2   인천광역시            (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL
# 3   인천광역시                  그린에너지            인천 계양구 솔고개길 2   S-OIL
# 4   인천광역시  현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크
# 5   인천광역시                 동양동주유소     인천 계양구 벌말로 328 (동양동)   GS칼텍스
# 6   인천광역시                  미래주유소    인천 계양구 경명대로 966 (계산동)   SK에너지
# 7   인천광역시         (주)스타에너지상사 계양점           인천 계양구 벌말로 545   GS칼텍스
# 8   인천광역시        SK KH에너지 에이원주유소      인천 계양구 벌말로 583(하야동)   SK에너지
# 9   인천광역시                  상야주유소        인천 계양구 벌말로584번길 1   S-OIL
# 10  인천광역시                  명품주유소    인천 계양구 경명대로 971 (계산동)   GS칼텍스
# 11  인천광역시          서일석유(주) 갈현주유소    인천 계양구  드림로 764 (갈현동)   GS칼텍스
# 12  인천광역시                  박촌주유소    인천 계양구 장제로 1021 (박촌동)  현대오일뱅크
# 13  인천광역시       SK에너지(주) 행복날개주유소     인천 계양구 계양대로 93 (작전동)   SK에너지
# 14  인천광역시              (주)보라미주유소       인천 계양구 장기로 7 (장기동)  현대오일뱅크
# 15  인천광역시                  계현주유소    인천 계양구 장제로 1263 (장기동)   SK에너지
# 16  인천광역시                   오주유소          인천 계양구 아나지로 553  현대오일뱅크
# 17  인천광역시           동일석유(주)동일주유소    인천 계양구 아나지로 283 (작전동)   SK에너지
# 18  인천광역시                  믿음주유소    인천 계양구 아나지로 557 (서운동)   S-OIL
# 19  인천광역시                  양정주유소    인천 계양구 아나지로 597 (서운동)   알뜰주유소
# 20  인천광역시          삼미상사(주)북인천주유소   인천 계양구 경명대로 1082 (계산동)   SK에너지
# 21  인천광역시      지에스칼텍스(주)계산신도시주유소          인천 계양구 봉오대로 942   GS칼텍스
# 22  인천광역시        SK에너지(주) 하나원주유소    인천 계양구 아나지로 426 (작전동)   SK에너지
# 23  인천광역시            토마토주유소(오류점)   인천 계양구 장제로 1456  (오류동)   S-OIL
# 24  인천광역시              임학주유소(셀프)   인천 계양구 경명대로 1161 (임학동)   SK에너지
# 25  인천광역시          서울석유(주) 태경주유소          인천 계양구 아나지로 554   SK에너지
# 26  인천광역시    현대오일뱅크(주)직영 유화셀프주유소    인천 계양구 아나지로 240 (효성동)  현대오일뱅크
# 27  인천광역시               영부에너지주유소    인천 계양구 아나지로 148 (효성동)   SK에너지
# 28  인천광역시                  미담주유소          인천 계양구 계양대로 108   SK에너지
# 29  인천광역시               (주)거보주유소    인천 계양구 아나지로 130 (효성동)   GS칼텍스
#
#             전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0   032-555-9143    Y     -  1559  1817     -
# 1   032-554-2994    Y     -  1575  1835     -
# 2   032-542-3154    Y     -  1577  1847     -
# 3   032-584-5189    N     -  1584  1834  1650
# 4   032-552-5185    Y  1999  1584  1844     -
# 5   032-513-5831    Y     -  1585  1835     -
# 6   032-553-0001    Y     -  1585  1835  1700
# 7   032-543-5104    Y     -  1585  1835     -
# 8   032-543-6395    Y     -  1585  1835  1640
# 9   032-555-7242    Y     -  1585  1835  1635
# 10  032-546-0777    Y     -  1585  1835     -
# 11  032-513-8903    N     -  1585  1855     -
# 12  032-519-9922    Y     -  1587  1834     -
# 13  032-542-9601    Y     -  1595  1865  1650
# 14  032-541-2175    Y     -  1595  1885  1700
# 15  032-514-5141    Y     -  1595  1865  1700
# 16  032-554-5189    N     -  1595  1855  1800
# 17  032-542-0052    Y     -  1595  1865  1650
# 18  032-553-2525    Y     -  1595  1855     -
# 19  032-555-4749    Y     -  1595  1855     -
# 20  032-545-2421    Y     -  1605  1855     -
# 21  032-543-8951    Y  1819  1609  1889  1610
# 22  032-544-5151    N     -  1615  1875     -
# 23  032-552-5189    Y     -  1615  1885     -
# 24  032-548-5189    Y     -  1615  1865     -
# 25  032-555-5189    Y     -  1615  1885     -
# 26  032-553-5189    Y  1999  1617  1889  1620
# 27  032-548-5501    Y     -  1625  1885  1700
# 28  032-556-5182    Y     -  1625  1885  1700
# 29  032-545-5145    N     -  1625  1895  1679

# %%
stations = pd.concat(tmp_list)
stations.shape
# Out:
# (319, 10)

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 319 entries, 0 to 26
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      319 non-null    object
#  1   상호      319 non-null    object
#  2   주소      319 non-null    object
#  3   상표      319 non-null    object
#  4   전화번호    319 non-null    object
#  5   셀프여부    319 non-null    object
#  6   고급휘발유   319 non-null    object
#  7   휘발유     319 non-null    object
#  8   경유      319 non-null    object
#  9   실내등유    319 non-null    object
# dtypes: object(10)
# memory usage: 27.4+ KB

# %%
stations.head()
# Out:
#       지역                     상호                       주소      상표  \
# 0  인천광역시                원천제2주유소           인천 계양구 벌말로 295   알뜰주유소
# 1  인천광역시          씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL
# 2  인천광역시            (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL
# 3  인천광역시                  그린에너지            인천 계양구 솔고개길 2   S-OIL
# 4  인천광역시  현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크
#
#            전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0  032-555-9143    Y     -  1559  1817     -
# 1  032-554-2994    Y     -  1575  1835     -
# 2  032-542-3154    Y     -  1577  1847     -
# 3  032-584-5189    N     -  1584  1834  1650
# 4  032-552-5185    Y  1999  1584  1844     -

# %% [markdown]
# ## 원하는 컬럼만 가져오기

# %%
stations_sel = stations.loc[:,['상호','주소','상표','셀프여부','휘발유']]
stations_sel
# Out:
#                        상호                       주소      상표 셀프여부   휘발유
# 0                 원천제2주유소           인천 계양구 벌말로 295   알뜰주유소    Y  1559
# 1           씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL    Y  1575
# 2             (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL    Y  1577
# 3                   그린에너지            인천 계양구 솔고개길 2   S-OIL    N  1584
# 4   현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크    Y  1584
# ..                    ...                      ...     ...  ...   ...
# 22                  화도주유소       인천 강화군 화도면 가능포로 37  현대오일뱅크    N  1698
# 23                  양갑주유소      인천 강화군 교동면 교동서로 274   SK에너지    N  1698
# 24                  한국주유소       인천 강화군 선원면 중앙로 445    자가상표    N  1719
# 25                  교동주유소    인천 강화군 교동면 대룡안길54번길 5   GS칼텍스    N  1720
# 26               백마외포리주유소      인천 강화군 내가면 중앙로 1301   S-OIL    N  1790
#
# [319 rows x 5 columns]

# %% [markdown]
# ## 컬럼명 변경하기

# %%
stations_sel.columns = ['주유소','주소','상표','셀프여부','가격']
stations_sel
# Out:
#                       주유소                       주소      상표 셀프여부    가격
# 0                 원천제2주유소           인천 계양구 벌말로 295   알뜰주유소    Y  1559
# 1           씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL    Y  1575
# 2             (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL    Y  1577
# 3                   그린에너지            인천 계양구 솔고개길 2   S-OIL    N  1584
# 4   현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크    Y  1584
# ..                    ...                      ...     ...  ...   ...
# 22                  화도주유소       인천 강화군 화도면 가능포로 37  현대오일뱅크    N  1698
# 23                  양갑주유소      인천 강화군 교동면 교동서로 274   SK에너지    N  1698
# 24                  한국주유소       인천 강화군 선원면 중앙로 445    자가상표    N  1719
# 25                  교동주유소    인천 강화군 교동면 대룡안길54번길 5   GS칼텍스    N  1720
# 26               백마외포리주유소      인천 강화군 내가면 중앙로 1301   S-OIL    N  1790
#
# [319 rows x 5 columns]

# %% [markdown]
# ## 군/구 정보만 추출하기(군/구 컬럼추가)

# %%
# '연수구'와 같은 군/구 정보만 추출하기
# '인천 계양구 벌말로 295' -> '계양구'

gu_list  = []

for address in stations['주소']:
    address_gu = address.split()[1]
    gu_list.append(address_gu)
    
stations_sel['군/구'] = gu_list
stations_sel
# Out:
#                       주유소                       주소      상표 셀프여부    가격  군/구
# 0                 원천제2주유소           인천 계양구 벌말로 295   알뜰주유소    Y  1559  계양구
# 1           씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL    Y  1575  계양구
# 2             (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL    Y  1577  계양구
# 3                   그린에너지            인천 계양구 솔고개길 2   S-OIL    N  1584  계양구
# 4   현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크    Y  1584  계양구
# ..                    ...                      ...     ...  ...   ...  ...
# 22                  화도주유소       인천 강화군 화도면 가능포로 37  현대오일뱅크    N  1698  강화군
# 23                  양갑주유소      인천 강화군 교동면 교동서로 274   SK에너지    N  1698  강화군
# 24                  한국주유소       인천 강화군 선원면 중앙로 445    자가상표    N  1719  강화군
# 25                  교동주유소    인천 강화군 교동면 대룡안길54번길 5   GS칼텍스    N  1720  강화군
# 26               백마외포리주유소      인천 강화군 내가면 중앙로 1301   S-OIL    N  1790  강화군
#
# [319 rows x 6 columns]

# %%
# 군/구 목록 확인
stations_sel['군/구'].unique()
# Out:
# array(['계양구', '남동구', '동구', '미추홀구', '남구', '부평구', '서구', '연수구', '옹진군', '중구',
#        '강화군'], dtype=object)

# %%
# 예외 처리하기
stations_sel.query("가격 == '-'")
# Out:
#                주유소                      주소     상표 셀프여부 가격   군/구
# 29  에스지씨솔루션㈜ 인천1지점    인천 미추홀구 아암대로253번길 14  GS칼텍스    N  -  미추홀구
# 30         태하셀프주유소  인천 미추홀구 한나루로 459 (용현동)  SK에너지    Y  -  미추홀구
# 38    동일석유(주)성신주유소           인천 중구 인중로 154  SK에너지    N  -    중구

# %%
# 가격이 기입되어 있지 않은 주유소 제외하기
stations_sel = stations_sel.query("가격 != '-'")
stations_sel
# Out:
#                       주유소                       주소      상표 셀프여부    가격  군/구
# 0                 원천제2주유소           인천 계양구 벌말로 295   알뜰주유소    Y  1559  계양구
# 1           씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL    Y  1575  계양구
# 2             (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL    Y  1577  계양구
# 3                   그린에너지            인천 계양구 솔고개길 2   S-OIL    N  1584  계양구
# 4   현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크    Y  1584  계양구
# ..                    ...                      ...     ...  ...   ...  ...
# 22                  화도주유소       인천 강화군 화도면 가능포로 37  현대오일뱅크    N  1698  강화군
# 23                  양갑주유소      인천 강화군 교동면 교동서로 274   SK에너지    N  1698  강화군
# 24                  한국주유소       인천 강화군 선원면 중앙로 445    자가상표    N  1719  강화군
# 25                  교동주유소    인천 강화군 교동면 대룡안길54번길 5   GS칼텍스    N  1720  강화군
# 26               백마외포리주유소      인천 강화군 내가면 중앙로 1301   S-OIL    N  1790  강화군
#
# [316 rows x 6 columns]

# %%
# 가격을 숫자(int)으로 변경하기
price_list = []

for price in stations_sel['가격']:
    price_new = int(price)
    price_list.append(price_new)
    
stations_sel['가격'] = price_list
stations_sel
# Out:
# C:\Users\minye\AppData\Local\Temp\ipykernel_14400\90076957.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stations_sel['가격'] = price_list
#                       주유소                       주소      상표 셀프여부    가격  군/구
# 0                 원천제2주유소           인천 계양구 벌말로 295   알뜰주유소    Y  1559  계양구
# 1           씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL    Y  1575  계양구
# 2             (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL    Y  1577  계양구
# 3                   그린에너지            인천 계양구 솔고개길 2   S-OIL    N  1584  계양구
# 4   현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크    Y  1584  계양구
# ..                    ...                      ...     ...  ...   ...  ...
# 22                  화도주유소       인천 강화군 화도면 가능포로 37  현대오일뱅크    N  1698  강화군
# 23                  양갑주유소      인천 강화군 교동면 교동서로 274   SK에너지    N  1698  강화군
# 24                  한국주유소       인천 강화군 선원면 중앙로 445    자가상표    N  1719  강화군
# 25                  교동주유소    인천 강화군 교동면 대룡안길54번길 5   GS칼텍스    N  1720  강화군
# 26               백마외포리주유소      인천 강화군 내가면 중앙로 1301   S-OIL    N  1790  강화군
#
# [316 rows x 6 columns]

# %%
stations_sel = stations_sel.query("가격 != '-'").copy() # 경고 해결하기
stations_sel
# Out:
#                       주유소                       주소      상표 셀프여부    가격  군/구
# 0                 원천제2주유소           인천 계양구 벌말로 295   알뜰주유소    Y  1559  계양구
# 1           씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL    Y  1575  계양구
# 2             (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL    Y  1577  계양구
# 3                   그린에너지            인천 계양구 솔고개길 2   S-OIL    N  1584  계양구
# 4   현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크    Y  1584  계양구
# ..                    ...                      ...     ...  ...   ...  ...
# 22                  화도주유소       인천 강화군 화도면 가능포로 37  현대오일뱅크    N  1698  강화군
# 23                  양갑주유소      인천 강화군 교동면 교동서로 274   SK에너지    N  1698  강화군
# 24                  한국주유소       인천 강화군 선원면 중앙로 445    자가상표    N  1719  강화군
# 25                  교동주유소    인천 강화군 교동면 대룡안길54번길 5   GS칼텍스    N  1720  강화군
# 26               백마외포리주유소      인천 강화군 내가면 중앙로 1301   S-OIL    N  1790  강화군
#
# [316 rows x 6 columns]

# %%
price_list = []

for price in stations_sel['가격']:
    price_new = int(price)
    price_list.append(price_new)
    
stations_sel['가격'] = price_list
stations_sel
# Out:
#                       주유소                       주소      상표 셀프여부    가격  군/구
# 0                 원천제2주유소           인천 계양구 벌말로 295   알뜰주유소    Y  1559  계양구
# 1           씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL    Y  1575  계양구
# 2             (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL    Y  1577  계양구
# 3                   그린에너지            인천 계양구 솔고개길 2   S-OIL    N  1584  계양구
# 4   현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크    Y  1584  계양구
# ..                    ...                      ...     ...  ...   ...  ...
# 22                  화도주유소       인천 강화군 화도면 가능포로 37  현대오일뱅크    N  1698  강화군
# 23                  양갑주유소      인천 강화군 교동면 교동서로 274   SK에너지    N  1698  강화군
# 24                  한국주유소       인천 강화군 선원면 중앙로 445    자가상표    N  1719  강화군
# 25                  교동주유소    인천 강화군 교동면 대룡안길54번길 5   GS칼텍스    N  1720  강화군
# 26               백마외포리주유소      인천 강화군 내가면 중앙로 1301   S-OIL    N  1790  강화군
#
# [316 rows x 6 columns]

# %%
stations_sel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   주유소     316 non-null    object
#  1   주소      316 non-null    object
#  2   상표      316 non-null    object
#  3   셀프여부    316 non-null    object
#  4   가격      316 non-null    int64
#  5   군/구     316 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 17.3+ KB

# %%
# 여러 개의 엑셀 파일을 합쳤기 때문에 인덱스가 꼬여있을 수 있으므로 reset_index를 이용하여
# 처음부터 다시 기록
stations_sel.reset_index(inplace=True)
stations_sel
# Out:
#      index                    주유소                       주소      상표 셀프여부    가격  \
# 0        0                원천제2주유소           인천 계양구 벌말로 295   알뜰주유소    Y  1559
# 1        1          씨앤에스유통신도시 주유소   인천 계양구  봉오대로 391 (효성동)   S-OIL    Y  1575
# 2        2            (주)오일리오인천지점     인천 계양구 장제로 936 (병방동)   S-OIL    Y  1577
# 3        3                  그린에너지            인천 계양구 솔고개길 2   S-OIL    N  1584
# 4        4  현대오일뱅크(주)직영 계양IC셀프주유소  인천 계양구 서부간선로 250  (박촌동)  현대오일뱅크    Y  1584
# ..     ...                    ...                      ...     ...  ...   ...
# 311     22                  화도주유소       인천 강화군 화도면 가능포로 37  현대오일뱅크    N  1698
# 312     23                  양갑주유소      인천 강화군 교동면 교동서로 274   SK에너지    N  1698
# 313     24                  한국주유소       인천 강화군 선원면 중앙로 445    자가상표    N  1719
# 314     25                  교동주유소    인천 강화군 교동면 대룡안길54번길 5   GS칼텍스    N  1720
# 315     26               백마외포리주유소      인천 강화군 내가면 중앙로 1301   S-OIL    N  1790
#
#      군/구
# 0    계양구
# 1    계양구
# 2    계양구
# 3    계양구
# 4    계양구
# ..   ...
# 311  강화군
# 312  강화군
# 313  강화군
# 314  강화군
# 315  강화군
#
# [316 rows x 7 columns]

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\minye\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\minye\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)

# %%
import matplotlib.pyplot as plt

plt.rc('font',family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.style.use("ggplot")

stations_sel.boxplot(column='가격',by='셀프여부',figsize=(12,8))
# Out:
# <AxesSubplot:title={'center':'가격'}, xlabel='셀프여부'>

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\minye\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\minye\anaconda3\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\minye\anaconda3\lib\site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\minye\anaconda3\lib\site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\minye\anaconda3\lib\site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\minye\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\minye\anaconda3\lib\site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\minye\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -idgetsnbextension (c:\users\minye\anaconda3\lib\site-packages)

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.boxplot(x='상표',y="가격",hue='셀프여부',data = stations_sel,palette="Set3")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.boxplot(x='상표',y="가격",hue='셀프여부',data = stations_sel,palette="summer")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.boxplot(x='군/구',y="가격",hue='셀프여부',data = stations_sel,palette="summer")
plt.show()
