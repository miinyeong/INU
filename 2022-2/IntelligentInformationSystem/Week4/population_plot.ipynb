# %%
import csv

f = open('incheon_population.csv','r')
data = csv.reader(f)
header = next(data)
for row in data:
    if '송도1동' in row[0]:
        print(row)

f.close()
# Out:
# ['인천광역시 연수구 송도1동(2818582000)', '18,724', '18,724', '64', '77', '110', '122', '126', '146', '158', '190', '179', '213', '240', '260', '269', '254', '309', '321', '234', '272', '301', '438', '326', '377', '419', '418', '353', '342', '302', '279', '287', '288', '291', '243', '204', '178', '177', '161', '176', '180', '193', '213', '226', '259', '275', '308', '238', '292', '264', '347', '352', '347', '369', '368', '356', '334', '353', '288', '293', '303', '255', '293', '265', '269', '261', '247', '211', '187', '171', '166', '133', '103', '137', '47', '85', '76', '58', '75', '50', '47', '34', '45', '44', '38', '35', '29', '16', '23', '12', '6', '14', '10', '1', '3', '4', '2', '7', '2', '1', '0', '0', '0', '0', '19,358', '19,358', '62', '76', '99', '102', '128', '132', '171', '186', '200', '197', '229', '244', '256', '264', '284', '285', '239', '261', '298', '338', '441', '421', '414', '352', '365', '287', '279', '289', '272', '271', '243', '218', '210', '188', '203', '195', '219', '200', '231', '259', '301', '338', '346', '342', '336', '324', '357', '371', '395', '389', '380', '438', '353', '367', '350', '300', '245', '288', '252', '280', '240', '275', '267', '244', '158', '174', '152', '159', '122', '108', '97', '57', '64', '77', '74', '73', '49', '56', '57', '49', '46', '52', '41', '43', '33', '20', '29', '29', '19', '30', '20', '22', '14', '12', '9', '9', '7', '5', '2', '2', '2']

# %%
import csv

f = open('incheon_population.csv','r')
data = csv.reader(f)
header = next(data)
for row in data:
    if '송도1동' in row[0]:
        for i in row[3:104]:
            print(i)

f.close()
# Out:
# 64
# 77
# 110
# 122
# 126
# 146
# 158
# 190
# 179
# 213
# 240
# 260
# 269
# 254
# 309
# 321
# 234
# 272
# 301
# 438
# 326
# 377
# 419
# 418
# 353
# 342
# 302
# 279
# 287
# 288
# 291
# 243
# 204
# 178
# 177
# 161
# 176
# 180
# 193
# 213
# 226
# 259
# 275
# 308
# 238
# 292
# 264
# 347
# 352
# 347
# 369
# 368
# 356
# 334
# 353
# 288
# 293
# 303
# 255
# 293
# 265
# 269
# 261
# 247
# 211
# 187
# 171
# 166
# 133
# 103
# 137
# 47
# 85
# 76
# 58
# 75
# 50
# 47
# 34
# 45
# 44
# 38
# 35
# 29
# 16
# 23
# 12
# 6
# 14
# 10
# 1
# 3
# 4
# 2
# 7
# 2
# 1
# 0
# 0
# 0
# 0

# %%
import csv

f = open('incheon_population.csv','r')
data = csv.reader(f)
header = next(data)
male = []
for row in data:
    if '송도1동' in row[0]:
        for i in row[3:104]:
            male.append(int(i))
print(male)
f.close()
# Out:
# [64, 77, 110, 122, 126, 146, 158, 190, 179, 213, 240, 260, 269, 254, 309, 321, 234, 272, 301, 438, 326, 377, 419, 418, 353, 342, 302, 279, 287, 288, 291, 243, 204, 178, 177, 161, 176, 180, 193, 213, 226, 259, 275, 308, 238, 292, 264, 347, 352, 347, 369, 368, 356, 334, 353, 288, 293, 303, 255, 293, 265, 269, 261, 247, 211, 187, 171, 166, 133, 103, 137, 47, 85, 76, 58, 75, 50, 47, 34, 45, 44, 38, 35, 29, 16, 23, 12, 6, 14, 10, 1, 3, 4, 2, 7, 2, 1, 0, 0, 0, 0]

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot') #격자 무늬 스타일 지정
plt.plot(male)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font',family='Malgun Gothic')
plt.title('송도 1동 남성 연령별 인구수')
plt.style.use('ggplot')
plt.plot(male)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font',family='Malgun Gothic')
plt.title('송도 1동 남성 연령별 인구수')
plt.style.use('ggplot')
plt.xlabel('연령')
plt.ylabel('인구수')
plt.plot(male)
plt.show()

# %%
import csv

f = open('incheon_population.csv','r')
data = csv.reader(f)
header = next(data)

female= []
for row in data:
    if '송도1동' in row[0]:
        for i in row[106:207]:
            female.append(int(i))
print(female)
f.close()
# Out:
# [62, 76, 99, 102, 128, 132, 171, 186, 200, 197, 229, 244, 256, 264, 284, 285, 239, 261, 298, 338, 441, 421, 414, 352, 365, 287, 279, 289, 272, 271, 243, 218, 210, 188, 203, 195, 219, 200, 231, 259, 301, 338, 346, 342, 336, 324, 357, 371, 395, 389, 380, 438, 353, 367, 350, 300, 245, 288, 252, 280, 240, 275, 267, 244, 158, 174, 152, 159, 122, 108, 97, 57, 64, 77, 74, 73, 49, 56, 57, 49, 46, 52, 41, 43, 33, 20, 29, 29, 19, 30, 20, 22, 14, 12, 9, 9, 7, 5, 2, 2, 2]

# %%
import matplotlib.pyplot as plt

plt.rc('font',family='Malgun Gothic')
plt.title('송도 1동 여성 연령별 인구수')
plt.style.use('ggplot')
plt.plot(female)
plt.xlabel('연령')
plt.ylabel('인구수')
plt.show()

# %%
import csv

f = open('incheon_population.csv','r')
data = csv.reader(f)
header = next(data)

result=[]
for row in data:
    if '송도1동' in row[0]:
        for male, female in zip(row[3:104],row[106:207]):
            result.append(int(male)+int(female))
print(result)
f.close()
# Out:
# [126, 153, 209, 224, 254, 278, 329, 376, 379, 410, 469, 504, 525, 518, 593, 606, 473, 533, 599, 776, 767, 798, 833, 770, 718, 629, 581, 568, 559, 559, 534, 461, 414, 366, 380, 356, 395, 380, 424, 472, 527, 597, 621, 650, 574, 616, 621, 718, 747, 736, 749, 806, 709, 701, 703, 588, 538, 591, 507, 573, 505, 544, 528, 491, 369, 361, 323, 325, 255, 211, 234, 104, 149, 153, 132, 148, 99, 103, 91, 94, 90, 90, 76, 72, 49, 43, 41, 35, 33, 40, 21, 25, 18, 14, 16, 11, 8, 5, 2, 2, 2]

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
plt.title('송도1동 연령별 인구수')
plt.style.use('ggplot')
plt.plot(result)
plt.xlabel('연령')
plt.ylabel('인구수')
plt.show()

# %% [markdown]
# # 인천의 다른 구역 연령별 인구수 구하기

# %%
import csv
import matplotlib.pyplot as plt

f= open('incheon_population.csv','r')
data = csv.reader(f)

result = []
name = input('인구 구조를 알고 싶은 동의 이름 : ')

for row in data:
    if name in row[0]:
        for male,female in zip(row[3:104],row[106:207]):
            result.append(int(male)+int(female))
f.close()

plt.rc('font',family='Malgun Gothic')
plt.title(name+' 연령별 인구수')
plt.style.use('ggplot')
plt.plot(result)
plt.xlabel('연령')
plt.ylabel('인구수')
plt.show()

# %% [markdown]
# # 인천의 다른 구역 연령별 인구수 구하기

# %%
import csv
import matplotlib.pyplot as plt

f = open('incheon_population.csv','r')
data = csv.reader(f)

result =[]
name = input('인구 구조를 알고 싶은 동 이름 입력: ')

for row in data:
    if name in row[0]:
        for m,fm in zip(row[3,104],row[106,207]):
            result.append(int(m)+int(fm))
f.close()

plt.style.use('ggplot')
plt.rc('font',family='Gulim')
plt.title(name + '의 연령별 인구수')
plt.plot(result)
plt.xlabel('연령')
plt.ylabel('인구수')
plt.show()
